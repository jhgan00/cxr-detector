# %%
import cv2
import pydicom
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
np.random.seed(0)

# %%
base_dir = "stage_2_train_images"
dcm_list = [base_dir + "/" + fname for fname in os.listdir("stage_2_train_images")]
np.random.shuffle(dcm_list)
test_imgs = dcm_list[:200]

# %%
def get_dcm_array(filepath):
    return pydicom.read_file(filepath).pixel_array

# %%
plt.imshow(get_dcm_array(dcmfile), cmap="gray")

# %%
for dcmfile in tqdm(test_imgs):
    fname = dcmfile.split("/")[-1].split(".")[0]
    arr = get_dcm_array(dcmfile)
    cv2.imwrite(f"kaggle-test/{fname}.png", arr)
